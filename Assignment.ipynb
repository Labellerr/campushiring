# %% [markdown]
# <a href="https://colab.research.google.com/github/Saksham2905/campushiring/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 69.3 MB/s eta 0:00:00
# ...

# %%
# Unzip the file into a new folder called 'Vehicle_Dataset'
# !unzip /content/DataSet_export.zip -d /content/Vehicle_Dataset
# Out:
# Archive:  /content/DataSet_export.zip
#    creating: /content/Vehicle_Dataset/images/
#    creating: /content/Vehicle_Dataset/labels/
#   inflating: /content/Vehicle_Dataset/classes.txt
#   inflating: /content/Vehicle_Dataset/data.yaml
#   inflating: /content/Vehicle_Dataset/labels/26_jpg.rf.5fc2944bf44299051c3c1c4fb9469774.txt
#   inflating: /content/Vehicle_Dataset/labels/115_jpg.rf.975b1e3d8cfd7563e8605a76e4f70979.txt
#   inflating: /content/Vehicle_Dataset/labels/128_jpg.rf.3d5ec0e3299adc451e6c2651a1f6232e.txt
#   inflating: /content/Vehicle_Dataset/labels/Asraf_15_jpg.rf.a6323459104fa2e34633620fe3566f22.txt
#   inflating: /content/Vehicle_Dataset/labels/Dipto_-147_jpg.rf.90db27926fb450a72ddfc871185de65b.txt
#   inflating: /content/Vehicle_Dataset/labels/Train11.txt
#   inflating: /content/Vehicle_Dataset/labels/100_jpg.rf.971dbb99e07828d1655d69bbfb7136be.txt
#   inflating: /content/Vehicle_Dataset/labels/Train 28.txt
#   inflating: /content/Vehicle_Dataset/labels/Train 33.txt
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')

# Run the training again
results = model.train(
    data='Vehicle_Dataset/data.yaml', # Make sure this path is correct
    epochs=100,
    imgsz=416,
    cache=True,
    device=0
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load your custom-trained model from the results folder
model = YOLO('/content/runs/segment/train/weights/best.pt')

# Define the path to your folder of test images
# Make sure you have uploaded this folder!
test_image_folder = '/content/Vehicle_Dataset/Test_Images'

# Run inference and save the predictions
# save=True will save the images with masks drawn on them
# save_txt=True will save the prediction coordinates in text files (important for a later step)
results = model.predict(source=test_image_folder, save=True, save_txt=True)

print("Inference complete!")
# Out:
# image 1/120 /content/Vehicle_Dataset/Test_Images/100_jpg.rf.971dbb99e07828d1655d69bbfb7136be.jpg: 256x416 7 Vehicless, 68.1ms
# image 2/120 /content/Vehicle_Dataset/Test_Images/101_jpg.rf.2737e79396d350c7eeb5bf867c346077.jpg: 320x416 16 Vehicless, 48.8ms
# image 3/120 /content/Vehicle_Dataset/Test_Images/102_jpg.rf.2d884248dcc60b7d6b93f61df77921df.jpg: 192x416 6 Pedestrians, 10 Vehicless, 47.3ms
# image 4/120 /content/Vehicle_Dataset/Test_Images/103_jpg.rf.cb820e037e0ccc6163377e9ead1fea10.jpg: 288x416 8 Vehicless, 47.7ms
# image 5/120 /content/Vehicle_Dataset/Test_Images/104_jpg.rf.69544ebdaf59239e1d742da7bde4afb4.jpg: 416x320 3 Vehicless, 47.5ms
# image 6/120 /content/Vehicle_Dataset/Test_Images/105_jpg.rf.cbfae4b633dff2527e3514746c223f05.jpg: 416x320 2 Vehicless, 7.5ms
# image 7/120 /content/Vehicle_Dataset/Test_Images/106_jpg.rf.256148b75cf465e3e6f69d7c092fe9d9.jpg: 416x320 3 Pedestrians, 2 Vehicless, 6.6ms
# ...
