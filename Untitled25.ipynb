# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshat3422/akshat_gupta/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os
os.makedirs("/content/final_label", exist_ok=True)
with zipfile.ZipFile("/content/final_label.zip") as file:
  file.extractall("/content/final_label")

# %%
os.makedirs("/content/final_label/images/train",exist_ok=True)
with zipfile.ZipFile("/content/train.zip",'r') as train:
  train.extractall("/content/final_label/images/train")

# %%
import os
import shutil

# Define the source and destination paths
source_dir = "/content/final_label/images/train/Train_Images"
destination_dir = "/content/final_label/images/train"

# Check if the source directory exists
if os.path.isdir(source_dir):
    print(f"Moving files from '{source_dir}' to '{destination_dir}'...")

    # Iterate through all files in the source directory
    for filename in os.listdir(source_dir):
        # Create full file paths
        source_path = os.path.join(source_dir, filename)
        destination_path = os.path.join(destination_dir, filename)

        # Move the file
        try:
            shutil.move(source_path, destination_path)
            print(f"Successfully moved: {filename}")
        except Exception as e:
            print(f"Failed to move {filename}: {e}")

    # After moving the files, remove the empty source directory
    try:
        os.rmdir(source_dir)
        print(f"\nRemoved empty directory: {source_dir}")
    except OSError as e:
        print(f"\nError removing directory: {e}")
else:
    print(f"Directory '{source_dir}' not found. Please check the path. 🔍")

print("\nMove operation complete.")
# Out:
# Directory '/content/final_label/images/train/Train_Images' not found. Please check the path. 🔍
#
# Move operation complete.

# %%
import os
import shutil

# Path where all your txt files currently are
source_dir = '/content/final_label/labels'  # change if your files are elsewhere

# Path to your train folder
train_dir = '/content/final_label/labels/train'  # create if doesn't exist
os.makedirs(train_dir, exist_ok=True)

# Loop through files and move .txt files to train folder
for file in os.listdir(source_dir):
    if file.endswith('.txt'):
        src_path = os.path.join(source_dir, file)
        dst_path = os.path.join(train_dir, file)
        shutil.move(src_path, dst_path)

print("All .txt files moved to train folder!")
# Out:
# All .txt files moved to train folder!

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Paths
data_dir = '/content/final_label'
images_dir = os.path.join(data_dir, 'images')
labels_dir = os.path.join(data_dir, 'labels')

train_images_dir = os.path.join(images_dir, 'train')
train_labels_dir = os.path.join(labels_dir, 'train')
val_images_dir = os.path.join(images_dir, 'val')
val_labels_dir = os.path.join(labels_dir, 'val')

# Create val directories
os.makedirs(val_images_dir, exist_ok=True)
os.makedirs(val_labels_dir, exist_ok=True)

# Get all image and label files
image_files = [f for f in os.listdir(train_images_dir) if f.endswith(('.jpg', '.png'))]
label_files = [f for f in os.listdir(train_labels_dir) if f.endswith('.txt')]

# Match images with labels
dataset = [(img, os.path.splitext(img)[0] + '.txt') for img in image_files if os.path.splitext(img)[0] + '.txt' in label_files]

# Select 20 images for validation
val_set = dataset[:20]
train_set = dataset[20:]

# Move validation files
for img_file, label_file in val_set:
    shutil.move(os.path.join(train_images_dir, img_file), os.path.join(val_images_dir, img_file))
    shutil.move(os.path.join(train_labels_dir, label_file), os.path.join(val_labels_dir, label_file))

print(f"Training images: {len(train_set)}, Validation images: {len(val_set)}")
# Out:
# Training images: 60, Validation images: 20

# %%
# !pip install ultralytics

# %%
# !yolo task=segment mode=train model=yolo11n-seg.pt data=/content/final_label/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git remote add origin https://github.com/Labellerr/campushiring.git

# %%
# !git add .

# %%
# !git pull rebase
# Out:
# fatal: 'rebase' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/.git/

# %%
# !git remote set-url origin <https://github.com/Akshat3422/akshat_gupta.git>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `git remote set-url origin <https://github.com/Akshat3422/akshat_gupta.git>'

# %%
# !git clone https://github.com/Akshat3422/akshat_gupta.git
# Out:
# Cloning into 'akshat_gupta'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 2 (from 1)
# Receiving objects: 100% (3/3), done.

# %%
# !cd campushiring
# Out:
# /bin/bash: line 1: cd: campushiring: No such file or directory

# %%
# !git config --global user.name "Akshat3422"
# !git config --global user.email "akshat4899@gmail.com"

# %%
# !git add final_label

# %%
# !git commit -m "full_project"
# Out:
# [master (root-commit) af2246b] full_project
#  379 files changed, 52421 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/default_configs.db
#  create mode 100644 .config/gce
#  create mode 100644 .config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
#  create mode 100644 .config/logs/2025.09.19/13.39.59.525129.log
#  create mode 100644 .config/logs/2025.09.19/13.40.21.959342.log
#  create mode 100644 .config/logs/2025.09.19/13.40.30.940050.log
#  create mode 100644 .config/logs/2025.09.19/13.40.32.438351.log
#  create mode 100644 .config/logs/2025.09.19/13.40.41.341666.log
#  create mode 100644 .config/logs/2025.09.19/13.40.42.120946.log
# ...

# %%
# !git remote add origin https://github.com/Akshat3422/akshat_gupta.git
# Out:
# error: remote origin already exists.

# %%
# !git branch
# Out:
# * master

# %%
# !git push origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git clone https://github.com/<your-username>/campushiring.git
# Out:
# /bin/bash: line 1: your-username: No such file or directory

# %%
# !cd campushiring
# Out:
# /bin/bash: line 1: cd: campushiring: No such file or directory

# %%
# !git clone https://github.com/<Akshat3422>/campushiring.git
# Out:
# /bin/bash: line 1: Akshat3422: No such file or directory
