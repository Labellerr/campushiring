# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv8 segmentation model
model = YOLO('yolov8n-seg.pt')

# Train the model on your dataset
# I've corrected the path to your data.yaml file below
results = model.train(
   data='/content/drive/My Drive/collab_data/data/data.yml',
   epochs=100,
   imgsz=640,
   project='/content/drive/My Drive/YOLO_outputs',  # folder in Drive
)
# Out:
# ...
# Ultralytics 8.3.202 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# %%
# 1. Load your custom-trained model
model = YOLO('/content/drive/MyDrive/collab_data/data/model_training/train/weights/best.pt')

# %%
# 2. Define the path to your test images
test_images_path = '/content/drive/My Drive/collab_data/data/test'

# 3. Run inference on the test images
results = model.predict(
    source=test_images_path,
    save=True,
    save_txt=True,
    project='/content/drive/My Drive/collab_data/result'

)
# Out:
# image 1/48 /content/drive/My Drive/collab_data/data/test/BDD100K-67.jpg: 384x640 16 Vehicles, 50.2ms
# image 2/48 /content/drive/My Drive/collab_data/data/test/BDD100K-69.jpg: 384x640 3 Vehicles, 9.5ms
# image 3/48 /content/drive/My Drive/collab_data/data/test/BDD100K-74.jpg: 384x640 7 Vehicles, 9.3ms
# image 4/48 /content/drive/My Drive/collab_data/data/test/BDD100K-75.jpg: 384x640 14 Vehicles, 7.6ms
# image 5/48 /content/drive/My Drive/collab_data/data/test/BDD100K-76.jpg: 384x640 3 Vehicles, 7.8ms
# image 6/48 /content/drive/My Drive/collab_data/data/test/BDD100K-79.jpg: 384x640 9 Vehicles, 1 Pedestrian, 9.3ms
# image 7/48 /content/drive/My Drive/collab_data/data/test/BDD100K-83.jpg: 384x640 4 Vehicles, 6 Pedestrians, 8.9ms
# image 8/48 /content/drive/My Drive/collab_data/data/test/BDD100K-84.jpg: 384x640 8 Vehicles, 13.4ms
# image 9/48 /content/drive/My Drive/collab_data/data/test/BDD100K-86.jpg: 384x640 5 Vehicles, 7.6ms
# ...
